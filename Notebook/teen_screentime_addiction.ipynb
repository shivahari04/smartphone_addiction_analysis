# %% [markdown]
# # Exploratory Data Analysis
#
# #### Teen Smartphone Addiction / Academic Performance
#
# [ Source: Kaggle.com](https://www.kaggle.com/datasets/sumedh1507/teen-phone-addiction)
#
# ***Survey based on 3000 Teenage Students - over 3 month***
#
# **Research Questions**
#
# 1. Addiction level impact Academic performance?
# 2. Higher phone usage impacts academic performance?
# 3. Can lack of sleep impact academic performance?
#
#
# Note: Data source is not very clear so it could potentially be a Synthetic dataset. No race, ethnicity, or socioeconomic column therefore, the addiction level or any type of patterns cannot be a general representation.

# %%
#import libraries
 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Reading CSV file

data = pd.read_csv("../Data/teen_screentime_addiction.csv") 
df = pd.DataFrame(data)

# %%
#First 5 lines of Dataframe

df.head()
# Out:
#    ID               Name  Age  Gender          Location School_Grade  \
# 0   1    Shannon Francis   13  Female        Hansonfort          9th
# 1   2    Scott Rodriguez   17  Female      Theodorefort          7th
# 2   3        Adrian Knox   13   Other       Lindseystad         11th
# 3   4  Brittany Hamilton   18  Female      West Anthony         12th
# 4   5       Steven Smith   14   Other  Port Lindsaystad          9th
#
#    Daily_Usage_Hours  Sleep_Hours  Academic_Performance  Social_Interactions  \
# 0                4.0          6.1                    78                    5
# 1                5.5          6.5                    70                    5
# 2                5.8          5.5                    93                    8
# 3                3.1          3.9                    78                    8
# 4                2.5          6.7                    56                    4
#
#    ...  Screen_Time_Before_Bed  Phone_Checks_Per_Day  Apps_Used_Daily  \
# ...

# %%
#Summary of DataFrame
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      3000 non-null   int64
#  1   Name                    3000 non-null   str
#  2   Age                     3000 non-null   int64
#  3   Gender                  3000 non-null   str
#  4   Location                3000 non-null   str
#  5   School_Grade            3000 non-null   str
#  6   Daily_Usage_Hours       3000 non-null   float64
#  7   Sleep_Hours             3000 non-null   float64
#  8   Academic_Performance    3000 non-null   int64
#  9   Social_Interactions     3000 non-null   int64
#  10  Exercise_Hours          3000 non-null   float64
#  11  Anxiety_Level           3000 non-null   int64
#  12  Depression_Level        3000 non-null   int64
#  13  Self_Esteem             3000 non-null   int64
# ...

# %%
#find rows and columns
df.shape
# Out:
# (3000, 25)

# %%
#View Descriptive statistics
df.describe()
# Out:
#                 ID          Age  Daily_Usage_Hours  Sleep_Hours  \
# count  3000.000000  3000.000000        3000.000000  3000.000000
# mean   1500.500000    15.969667           5.020667     6.489767
# std     866.169729     1.989489           1.956501     1.490713
# min       1.000000    13.000000           0.000000     3.000000
# 25%     750.750000    14.000000           3.700000     5.500000
# 50%    1500.500000    16.000000           5.000000     6.500000
# 75%    2250.250000    18.000000           6.400000     7.500000
# max    3000.000000    19.000000          11.500000    10.000000
#
#        Academic_Performance  Social_Interactions  Exercise_Hours  \
# count           3000.000000          3000.000000     3000.000000
# mean              74.947333             5.097667        1.040667
# std               14.684156             3.139333        0.734620
# min               50.000000             0.000000        0.000000
# ...

# %%
#Categorical columns
df.value_counts()
# Out:
# ID    Name               Age  Gender  Location          School_Grade  Daily_Usage_Hours  Sleep_Hours  Academic_Performance  Social_Interactions  Exercise_Hours  Anxiety_Level  Depression_Level  Self_Esteem  Parental_Control  Screen_Time_Before_Bed  Phone_Checks_Per_Day  Apps_Used_Daily  Time_on_Social_Media  Time_on_Gaming  Time_on_Education  Phone_Usage_Purpose  Family_Communication  Weekend_Usage_Hours  Addiction_Level
# 1     Shannon Francis    13   Female  Hansonfort        9th           4.0                6.1          78                    5                    0.1             10             3                 8            0                 1.4                     86                    19               3.6                   1.7             1.2                Browsing             4                     8.7                  10.0               1
# ...

# %%
# Breakdown of Gender
df['Gender'].value_counts()
# Out:
# Gender
# Male      1016
# Female    1007
# Other      977
# Name: count, dtype: int64

# %% [markdown]
# Dataset was clean to begin with. Gender is fairly balanced leads to believe it is a synthetic dataset since the raw original data are unlikely to be balanced.

# %%
#Age group
df['Age'].value_counts().sort_index()
# Out:
# Age
# 13    433
# 14    427
# 15    431
# 16    467
# 17    412
# 18    409
# 19    421
# Name: count, dtype: int64

# %%
#School Grade
df['School_Grade'].value_counts().sort_index(ascending= True)
# Out:
# School_Grade
# 10th    487
# 11th    479
# 12th    529
# 7th     497
# 8th     482
# 9th     526
# Name: count, dtype: int64

# %%
#filter with .loc - Daily Usage Hours

df.loc[df["Daily_Usage_Hours"] > 5].sort_values("Age", ascending=True)
# Out:
#         ID               Name  Age  Gender        Location School_Grade  \
# 2958  2959       Steven Brown   13  Female   Margaretville         10th
# 1295  1296     Christy Nelson   13  Female   South Heather          7th
# 43      44     Brittany Myers   13    Male      Nguyenfort         11th
# 2924  2925      Anna Castillo   13    Male     South James         10th
# 2923  2924      Donna Woodard   13   Other  Lake Davidbury          9th
# ...    ...                ...  ...     ...             ...          ...
# 1278  1279      Andrew Meyers   19   Other    Lewischester          7th
# 2945  2946       Daniel Grant   19   Other  Lake Taramouth          9th
# 41      42     Nicholas Gomez   19   Other      Roberttown         12th
# 1763  1764    Michael Collins   19  Female       North Amy          7th
# 2961  2962  Justin Williamson   19    Male       South Roy         12th
#
#       Daily_Usage_Hours  Sleep_Hours  Academic_Performance  \
# ...

# %%
#Sleephours
df.loc[df["Sleep_Hours"] > 4].sort_values("Sleep_Hours")
# Out:
#         ID                     Name  Age  Gender         Location  \
# 1585  1586  Dr. Christine Lopez DDS   14   Other      New Heather
# 1398  1399              John Thomas   15    Male        Lake Lynn
# 386    387              Matthew Lee   14    Male     Castillofurt
# 1415  1416           Melanie Morgan   16  Female   Catherineshire
# 2395  2396             Mary Leblanc   15   Other      Millermouth
# ...    ...                      ...  ...     ...              ...
# 67      68           Chelsey Dillon   18  Female       Franciston
# 94      95            Wesley Miller   18  Female        Sherryton
# 1965  1966            Brittany King   19  Female       East Janet
# 2057  2058           Amanda Sanford   18  Female  New Michaelfurt
# 1980  1981           Michelle Green   19    Male     Michelemouth
#
#      School_Grade  Daily_Usage_Hours  Sleep_Hours  Academic_Performance  \
# 1585          9th                5.4          4.1                    64
# ...

# %%
df.loc[(df['Gender'] == 'Male')]
# Out:
#         ID              Name  Age Gender        Location School_Grade  \
# 6        7      Hailey Moses   16   Male   North Jeffrey         11th
# 8        9      Edward Avila   13   Male         Leebury          8th
# 11      12     Ruben Walters   14   Male       Lake Mary         11th
# 19      20     Kathryn Perez   18   Male    South Thomas         12th
# 23      24     Desiree Brady   19   Male     East Amanda          9th
# ...    ...               ...  ...    ...             ...          ...
# 2979  2980     Travis Harris   14   Male  East Mariastad          7th
# 2982  2983     Luke Hamilton   14   Male        Ericland          9th
# 2988  2989      Angela Lyons   14   Male        Howebury          7th
# 2991  2992  Christina Davila   16   Male     Heatherfurt         11th
# 2999  3000    Curtis Johnson   17   Male  Lake Alexander         10th
#
#       Daily_Usage_Hours  Sleep_Hours  Academic_Performance  \
# 6                   6.3          6.7                    89
# ...

# %% [markdown]
# Note: Some entries in the Male column appear to have feminine names. This may impact the accuracy of the analysis.

# %%
df.loc[(df['Gender'] == 'Other')]
# Out:
#         ID                    Name  Age Gender           Location  \
# 2        3             Adrian Knox   13  Other        Lindseystad
# 4        5            Steven Smith   14  Other   Port Lindsaystad
# 7        8       Veronica Marshall   13  Other       Jenniferport
# 9       10            James Carter   18  Other        Prestonview
# 14      15           Edwin Lambert   15  Other      New Emilyberg
# ...    ...                     ...  ...    ...                ...
# 2987  2988  Miss Emily Jenkins DDS   13  Other      South Theresa
# 2989  2990     Christine Davenport   18  Other  East Jeffreyburgh
# 2992  2993          Joseph Watkins   15  Other          Emilystad
# 2993  2994          Sandra Acevedo   17  Other       Robertsville
# 2997  2998           Norman Hughes   14  Other         Rebeccaton
#
#      School_Grade  Daily_Usage_Hours  Sleep_Hours  Academic_Performance  \
# 2            11th                5.8          5.5                    93
# ...

# %%
#find null values
df.isnull().sum()
# Out:
# ID                        0
# Name                      0
# Age                       0
# Gender                    0
# Location                  0
# School_Grade              0
# Daily_Usage_Hours         0
# Sleep_Hours               0
# Academic_Performance      0
# Social_Interactions       0
# Exercise_Hours            0
# Anxiety_Level             0
# Depression_Level          0
# Self_Esteem               0
# Parental_Control          0
# Screen_Time_Before_Bed    0
# Phone_Checks_Per_Day      0
# Apps_Used_Daily           0
# Time_on_Social_Media      0
# Time_on_Gaming            0
# Time_on_Education         0
# Phone_Usage_Purpose       0
# Family_Communication      0
# Weekend_Usage_Hours       0
# Addiction_Level           0
# dtype: int64

# %%
# Checking for duplicates using functions.py
#df.duplicated()
import sys
sys.path.append("..")

from functions import check_duplicates
teen_df = check_duplicates(df, name="teen_screentime_addiction.csv")
# Out:
# teen_screentime_addiction.csv has duplicate rows: 0

# %%
#groupby- Average Academic performance by Time_on_Education and Daily_Usage_Hours
result = (
    df.groupby(["Time_on_Education", "Daily_Usage_Hours"])["Academic_Performance"].mean().reset_index().sort_values("Daily_Usage_Hours"))

print(result)
# Out:
#       Time_on_Education  Daily_Usage_Hours  Academic_Performance
# 0                   0.0                0.0                  72.0
# 828                 1.3                0.0                  66.2
# 891                 1.4                0.0                  65.0
# 955                 1.5                0.0                  83.0
# 550                 0.9                0.0                  89.0
# ...                 ...                ...                   ...
# 1234                1.9               10.9                  54.0
# 953                 1.4               11.0                  59.0
# 827                 1.2               11.0                  75.0
# 619                 0.9               11.2                  55.0
# 954                 1.4               11.5                  96.0
#
# [1434 rows x 3 columns]

# %%
#Average Anxiety level by Sleep hours and Addiction level
avg_anx = df.groupby(['Sleep_Hours','Addiction_Level'])['Anxiety_Level'].mean().reset_index().sort_index().round(2)
avg_anx
# Out:
#       Sleep_Hours  Addiction_Level  Anxiety_Level
# 0             3.0              7.1           6.00
# 1             3.0              7.2           6.00
# 2             3.0              7.6           2.00
# 3             3.0              8.3          10.00
# 4             3.0              9.0           1.00
# ...           ...              ...            ...
# 1215         10.0              9.2           4.00
# 1216         10.0              9.4           8.00
# 1217         10.0              9.8           7.00
# 1218         10.0              9.9           3.50
# 1219         10.0             10.0           5.78
#
# [1220 rows x 3 columns]

# %%
#Average Academic Performance by Addiction level

avg_academic = (df.groupby("Addiction_Level")["Academic_Performance"].mean().reset_index().sort_values("Addiction_Level").round(2))

print(avg_academic)
# Out:
#     Addiction_Level  Academic_Performance
# 0               1.0                 82.00
# 1               1.4                 75.00
# 2               2.0                 92.00
# 3               2.1                 86.50
# 4               2.2                 75.00
# ..              ...                   ...
# 75              9.6                 72.37
# 76              9.7                 75.14
# 77              9.8                 73.64
# 78              9.9                 76.90
# 79             10.0                 75.14
#
# [80 rows x 2 columns]

# %% [markdown]
# ### Scatter Plot to display relationship between Addiction level to Academic Performance
#
# ***Bivariate Analysis***
# ***X-Axis : Addiction level (Score:1-10)***
# ***Y-Axis : Academic Performance (Out of 100)***

# %%
#Scatter Plot to display relationship between addiction level to academic performance

plt.figure(figsize=(12,10))

plt.scatter(avg_academic['Addiction_Level'], avg_academic['Academic_Performance'], alpha =0.8)
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.suptitle("Relationship between Addiction Level and Academic Performance", fontweight = 'bold', fontsize = 18, color = "#772222")
plt.title('(Survey based on 3000 Teenage Students over 3 months)', fontsize=11, color='black', pad=8)
plt.xlabel("Addiction Level (Score: 1-10)", fontsize = 14, fontweight = 'bold', color= "#772222")
plt.ylabel("Academic Performance (Out of 100)", fontsize = 14, fontweight = 'bold', color = "#772222")

plt.annotate('Outlier', xy=(2.6, 53), xytext=(3.5, 54), fontsize=11, color='gray', arrowprops=dict(arrowstyle='->', color='gray'))

plt.ylim(0,100)
plt.tight_layout()
plt.show()

# %% [markdown]
# Scatter plot shows no significant impact on Academic Performance due to addiction level. Most Academic Performance score ranged between 70-85. Therefore, no visible upward or downward trend. One outlier was identified(Score: 53)

# %%
# Looking for column names to filter out the necessary numeric variables
df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Gender', 'Location', 'School_Grade',
#        'Daily_Usage_Hours', 'Sleep_Hours', 'Academic_Performance',
#        'Social_Interactions', 'Exercise_Hours', 'Anxiety_Level',
#        'Depression_Level', 'Self_Esteem', 'Parental_Control',
#        'Screen_Time_Before_Bed', 'Phone_Checks_Per_Day', 'Apps_Used_Daily',
#        'Time_on_Social_Media', 'Time_on_Gaming', 'Time_on_Education',
#        'Phone_Usage_Purpose', 'Family_Communication', 'Weekend_Usage_Hours',
#        'Addiction_Level'],
#       dtype='str')

# %%
# To find the correlation coefficient of the variables

df_corr = df[['Daily_Usage_Hours', 'Sleep_Hours', 'Academic_Performance', 'Parental_Control','Screen_Time_Before_Bed', 'Phone_Checks_Per_Day', 'Apps_Used_Daily',
       'Time_on_Social_Media', 'Time_on_Gaming', 'Time_on_Education','Family_Communication', 'Weekend_Usage_Hours',
       'Addiction_Level']].corr()   
df_corr
# Out:
#                         Daily_Usage_Hours  Sleep_Hours  Academic_Performance  \
# Daily_Usage_Hours                1.000000     0.016444              0.021345
# Sleep_Hours                      0.016444     1.000000             -0.000273
# Academic_Performance             0.021345    -0.000273              1.000000
# Parental_Control                 0.000970     0.005670              0.003186
# Screen_Time_Before_Bed           0.004935    -0.004313             -0.005825
# Phone_Checks_Per_Day             0.004749     0.005198             -0.017102
# Apps_Used_Daily                  0.022841     0.026436             -0.026136
# Time_on_Social_Media            -0.012620    -0.018288              0.036357
# Time_on_Gaming                  -0.010371     0.005798             -0.033734
# Time_on_Education                0.014265    -0.009756              0.016377
# Family_Communication             0.004427    -0.027040             -0.027859
# ...

# %% [markdown]
# ### Heat Map to view the correlation of numeric variables

# %%
# To see the correlation of numeric values

fig, ax = plt.subplots(figsize=(14, 14))

sns.heatmap(df_corr.round(2), annot=True, fmt=".2f", cmap='coolwarm', linewidths=0.5, annot_kws={'size': 10})
plt.suptitle('Teen Screentime Addiction Heatmap', fontsize=20, color= "#772222", fontweight = 'bold')
plt.title('(Survey based on 3000 Teenage Students over 3 months)', fontsize=11, color='black', pad=8)
plt.xticks(rotation=90, ha='center', fontsize=12)
plt.yticks(rotation=0, fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# This Heatmap shows the correlation between the numeric variables.
#
# Red = positive correlation (both go up together)
# Blue = negative correlation (one goes up, other goes down)
# White/light = no relationship
# The diagonal is always 1.00 — every variable perfectly correlates with itself
# Daily_Usage_Hours has 0.60 is the Strongest finding means more screen time equal to higher addiction
# Next, Apps_Used_Daily has 0.32 means More apps is equal to slightly higher addiction
# Another important score is Sleep_Hours of -0.22 (not a strong range) indicates that more sleep may slightly reduce addiction

# %% [markdown]
# ### To Check Daily usage distribution - Histogram

# %%
#To check the daily usage distribution

fig, ax = plt.subplots(figsize=(12, 12))  
ax.hist(df['Daily_Usage_Hours'], bins=20, alpha=0.9, color= 'steelblue', edgecolor = 'white')

fig.suptitle('Daily Usage Distribution', fontweight = 'bold', color= "#772222" , fontsize=20)
plt.title('(Survey based on 3,000 teenage students over 3 months)', fontsize=11, color='black', pad=8)
ax.set_xlabel('Daily phone usage (hours)', fontsize=15,fontweight = 'bold', color= "#772222" )  
ax.set_ylabel('Number of students', fontsize=15,fontweight = 'bold', color= "#772222" )         


mean_value = df['Daily_Usage_Hours'].mean()
ax.axvline(mean_value, color='red', linestyle='--', linewidth=1.5, label=f'Mean: {mean_value:.1f} hrs')
ax.legend()

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# The histogram displays a univariate analysis of daily phone usage. The data appears balanced with no extreme skew. The most common usage is around 5 hours per day, with the majority of students falling within the 3–8 hour range.

# %%
# To check any relationship between daily usage hour to addiction level
avg_addiction = df.groupby('Daily_Usage_Hours')['Addiction_Level'].mean().reset_index()
avg_addiction = avg_addiction[avg_addiction['Daily_Usage_Hours'] >= 0].sort_values('Daily_Usage_Hours').round(2)
print(avg_addiction)
# Out:
#      Daily_Usage_Hours  Addiction_Level
# 0                  0.0             5.08
# 1                  0.1             7.10
# 2                  0.2             4.77
# 3                  0.3             5.34
# 4                  0.4             4.05
# ..                 ...              ...
# 102               10.6            10.00
# 103               10.9            10.00
# 104               11.0            10.00
# 105               11.2            10.00
# 106               11.5            10.00
#
# [107 rows x 2 columns]

# %% [markdown]
# ### Average Addiction level Vs Daily Usage hours

# %%
#Line Chart representing Average Addiction level to Daily Usage Hours

fig, ax = plt.subplots(figsize=(10, 8))

ax.plot(avg_addiction['Daily_Usage_Hours'], avg_addiction['Addiction_Level'], linewidth=2, color='steelblue')

fig.suptitle('Daily Phone Usage (Hours) to Average Addiction Level', fontweight='bold', color="#772222", fontsize=18, y=0.98)
ax.set_title('(Survey based on 3,000 students over 3 months)', fontsize=12, color='gray')
ax.set_xlabel('Daily Phone Usage (Hours)', fontsize=15, color= "#772222", fontweight = 'bold')
ax.set_ylabel('Average addiction level (Out of 10)', fontsize=15, color= "#772222", fontweight = 'bold')

ax.yaxis.grid(True, linestyle='--', linewidth=0.4, color='gray', alpha=0.3)
ax.xaxis.grid(True, linestyle='--', linewidth=0.4, color='gray', alpha=0.3)
ax.set_axisbelow(True)


ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_xlim(0,12)
ax.set_ylim(0,10)


plt.tight_layout()
plt.show()

# %% [markdown]
# This line chart confirms a strong positive relationship between daily phone usage hours and average addiction level. The overall trend clearly shows that as daily phone usage increases, addiction level rises consistently. There is steady clear upward trend from 2 to 8 hours. It also shows Addiction level starts around 4-5 hours and students using 8+ hours consistently scored the maximum addiction level.

# %%
# To find out if lack of sleep impact academic performance

Sleep_Score = df.groupby('Sleep_Hours')['Academic_Performance'].mean().reset_index().round(2)
print(Sleep_Score)
# Out:
#     Sleep_Hours  Academic_Performance
# 0           3.0                 73.41
# 1           3.1                 80.00
# 2           3.2                 71.17
# 3           3.3                 70.50
# 4           3.4                 73.54
# ..          ...                   ...
# 66          9.6                 81.00
# 67          9.7                 75.00
# 68          9.8                 71.12
# 69          9.9                 69.78
# 70         10.0                 74.61
#
# [71 rows x 2 columns]

# %% [markdown]
# ### Correlation between Sleep Hours and Academic Performance

# %%
# Line chart to find out if lack of sleep impacts academic performance

fig, ax = plt.subplots(figsize=(10, 8))

ax.plot(Sleep_Score['Sleep_Hours'], Sleep_Score['Academic_Performance'], linewidth=2, color='steelblue')

fig.suptitle('Sleep Hours impact on Academic Performance', fontweight='bold', color="#772222", fontsize=18, y=.98)
ax.set_title('(Survey based on 3,000 students over 3 months)', fontsize=12, color='gray')
ax.set_xlabel('Sleep Hours', fontsize=15, color="#772222")
ax.set_ylabel('Academic Performance (Out of 100)', fontsize=15, color="#772222")

ax.yaxis.grid(True, linestyle='--', linewidth=0.4, color='gray', alpha=0.3)
ax.xaxis.grid(True, linestyle='--', linewidth=0.4, color='gray', alpha=0.3)
ax.set_axisbelow(True)

ax.set_xlim(0, 10)
ax.set_ylim(0, 100)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# This line chart shows no clear trend between sleep hours and academic performance. Scores remained consistently within the 70–80 range regardless of sleep duration, confirming the weak correlation of -0.22 (weaker range) identified in the heatmap.
