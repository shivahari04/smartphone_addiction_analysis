# %% [markdown]
# # Exploratory Data Analysis
# #### Global Smartphone addiction
#
# [ Source: Kaggle.com](https://www.kaggle.com/datasets/khushikyad001/global-mobile-phone-addiction-dataset)
#
# **Survey based on 3000 participants - (Age range: 12-70 years old)**
#
# **Research Questions**
#
# 1. Does daily smartphone usage predict addiction level?
# 2. Does addiction level correlate with mental health?

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np  
import sys

# %% [markdown]
# ***This dataframe has 34 columns, which causes the columns to get truncated when viewing it in the notebook. To avoid that, `set_option` was used to display all columns.***

# %%
pd.set_option('display.max_columns', 50)        # View all the columns without getting truncated

# %%
# Loading second dataset - CSV format

data = pd.read_csv("../data/global_smartphone_addiction.csv")
df = pd.DataFrame(data)

# %% [markdown]
# #### Step 1: Understanding the dataset
#
# 1. First 10 lines of dataframe
# 2. Dataframe Info
# 3. check for null values
# 4. Describe function to see the stats
# 5. Categorical Breakdown
# 6. Filtered views

# %%
# First 10 lines of dataframe
df.head(10)
# Out:
#    User_ID  Country  Age  Gender   Occupation Education_Level  Income_USD  \
# 0        1    India   32    Male  Salesperson     High School    43865.49
# 1        2       UK   26    Male       Artist        Master's    41868.19
# 2        3  Germany   70   Other       Doctor     High School    59636.51
# 3        4       UK   44  Female     Engineer             NaN    39022.07
# 4        5   Brazil   46   Other      Student             NaN     -783.98
# 5        6    Japan   34    Male      Student             PhD    19751.80
# 6        7    China   51    Male       Doctor        Master's    22956.76
# 7        8   Russia   68    Male  Salesperson     High School    62102.93
# 8        9  Nigeria   33   Other  Salesperson             NaN    26629.11
# 9       10    India   38   Other  Salesperson     High School    43121.39
#
#    Daily_Screen_Time_Hours  Phone_Unlocks_Per_Day  Social_Media_Usage_Hours  \
# 0                     5.81                     75                      0.84
# 1                     9.05                     61                      3.13
# 2                     5.76                     58                      2.12
# 3                     6.71                     80                      1.60
# 4                     6.31                    136                      1.51
# 5                     8.94                    129                      2.28
# 6                     4.18                     65                      1.75
# 7                    10.05                     87                      2.13
# 8                     7.45                     50                      2.02
# 9                     6.87                     95                      2.27
#
#    Gaming_Usage_Hours  Streaming_Usage_Hours  Messaging_Usage_Hours  \
# 0               -1.55                   3.36                   1.44
# 1                2.50                   0.80                   2.42
# 2                1.96                   1.84                   1.98
# 3                2.70                   1.90                   2.43
# 4                1.73                   1.48                   1.30
# 5                2.49                   0.97                   1.39
# 6                2.07                   0.33                   1.58
# 7                2.99                   1.67                   2.06
# 8                0.49                   2.41                   1.60
# 9                0.00                   2.44                   1.37
#
#    Work_Related_Usage_Hours  Sleep_Hours  Physical_Activity_Hours  \
# 0                      2.14         5.22                     1.32
# 1                      1.44         6.23                     0.66
# 2                      1.92         6.57                     1.93
# 3                      1.82         7.27                     0.94
# 4                      1.76         5.43                     1.04
# 5                      2.66         6.21                     1.14
# 6                      1.98         4.84                     1.33
# 7                      1.51         6.81                     1.43
# 8                      2.98         6.54                     1.40
# 9                      2.55         6.04                     1.55
#
#    Mental_Health_Score  Depression_Score  Anxiety_Score  Stress_Level  \
# 0                61.47             80.80          23.72         95.80
# 1                96.11             98.99          39.72         25.03
# 2                73.68             44.64          94.47         99.54
# 3                53.42             10.89           5.03         66.49
# 4                67.01             37.54          17.29         14.72
# 5                25.15             97.45          65.54         63.04
# 6                 4.94             27.16          80.16         83.20
# 7                44.33             95.16          20.94         62.53
# 8                55.45             59.96          95.10         95.94
# 9                85.13             38.30           4.32         33.65
#
#   Relationship_Status Has_Children Urban_or_Rural  \
# 0              Single           No          Rural
# 1     In Relationship           No          Rural
# 2              Single          Yes          Urban
# 3     In Relationship           No          Urban
# 4            Divorced           No          Urban
# 5             Married           No          Rural
# 6     In Relationship           No          Urban
# 7            Divorced          Yes          Rural
# 8            Divorced           No          Urban
# 9            Divorced           No          Urban
#
#    Time_Spent_With_Family_Hours  Online_Shopping_Hours  \
# 0                          1.70                   1.85
# 1                          0.90                   0.66
# 2                          1.69                  -0.14
# 3                          1.11                   0.17
# 4                          1.06                   0.58
# 5                          1.32                   0.40
# 6                          1.08                   0.88
# 7                          1.02                   0.77
# 8                          0.77                   0.10
# 9                          1.74                   1.82
#
#   Internet_Connection_Type Primary_Device_Brand  \
# 0                       5G                Other
# 1                       4G              Samsung
# 2                     WiFi              Samsung
# 3                       3G                Apple
# 4                       3G               Xiaomi
# 5                       5G               Xiaomi
# 6                     WiFi               Huawei
# 7                       5G              Samsung
# 8                       5G                Apple
# 9                       4G              OnePlus
#
#   Has_Screen_Time_Management_App Self_Reported_Addiction_Level  \
# 0                             No                           Low
# 1                            Yes                        Severe
# 2                            Yes                        Severe
# 3                            Yes                      Moderate
# 4                             No                          High
# 5                             No                           Low
# 6                            Yes                        Severe
# 7                            Yes                           Low
# 8                            Yes                          High
# 9                            Yes                          High
#
#    Monthly_Data_Usage_GB Has_Night_Mode_On  Age_First_Phone  \
# 0                  16.43               Yes               16
# 1                  32.87                No               12
# 2                  27.45                No               18
# 3                  30.85                No               17
# 4                  10.38               Yes               18
# 5                  17.51                No                8
# 6                  44.52                No               11
# 7                  26.66                No               12
# 8                  24.49                No                8
# 9                  29.05                No               14
#
#    Push_Notifications_Per_Day  Tech_Savviness_Score
# 0                         106                 39.36
# 1                         111                  9.45
# 2                          90                 50.27
# 3                          60                 30.82
# 4                         127                 21.70
# 5                          78                 14.38
# 6                          82                 79.63
# 7                         102                 52.16
# 8                          85                 31.52
# 9                         120                 97.40

# %% [markdown]
# #### Verifying datatypes

# %%
# To view the summary of the dataframe
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 34 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   User_ID                         3000 non-null   int64
#  1   Country                         3000 non-null   str
#  2   Age                             3000 non-null   int64
#  3   Gender                          3000 non-null   str
#  4   Occupation                      3000 non-null   str
#  5   Education_Level                 2388 non-null   str
#  6   Income_USD                      3000 non-null   float64
#  7   Daily_Screen_Time_Hours         3000 non-null   float64
#  8   Phone_Unlocks_Per_Day           3000 non-null   int64
#  9   Social_Media_Usage_Hours        3000 non-null   float64
#  10  Gaming_Usage_Hours              3000 non-null   float64
#  11  Streaming_Usage_Hours           3000 non-null   float64
#  12  Messaging_Usage_Hours           3000 non-null   float64
#  13  Work_Related_Usage_Hours        3000 non-null   float64
#  14  Sleep_Hours                     3000 non-null   float64
#  15  Physical_Activity_Hours         3000 non-null   float64
#  16  Mental_Health_Score             3000 non-null   float64
#  17  Depression_Score                3000 non-null   float64
#  18  Anxiety_Score                   3000 non-null   float64
#  19  Stress_Level                    3000 non-null   float64
#  20  Relationship_Status             3000 non-null   str
#  21  Has_Children                    3000 non-null   str
#  22  Urban_or_Rural                  3000 non-null   str
#  23  Time_Spent_With_Family_Hours    3000 non-null   float64
#  24  Online_Shopping_Hours           3000 non-null   float64
#  25  Internet_Connection_Type        3000 non-null   str
#  26  Primary_Device_Brand            3000 non-null   str
#  27  Has_Screen_Time_Management_App  3000 non-null   str
#  28  Self_Reported_Addiction_Level   3000 non-null   str
#  29  Monthly_Data_Usage_GB           3000 non-null   float64
#  30  Has_Night_Mode_On               3000 non-null   str
#  31  Age_First_Phone                 3000 non-null   int64
#  32  Push_Notifications_Per_Day      3000 non-null   int64
#  33  Tech_Savviness_Score            3000 non-null   float64
# dtypes: float64(17), int64(5), str(12)
# memory usage: 797.0 KB

# %%
# checking for null values
df.isnull().sum()
# Out:
# User_ID                             0
# Country                             0
# Age                                 0
# Gender                              0
# Occupation                          0
# Education_Level                   612
# Income_USD                          0
# Daily_Screen_Time_Hours             0
# Phone_Unlocks_Per_Day               0
# Social_Media_Usage_Hours            0
# Gaming_Usage_Hours                  0
# Streaming_Usage_Hours               0
# Messaging_Usage_Hours               0
# Work_Related_Usage_Hours            0
# Sleep_Hours                         0
# Physical_Activity_Hours             0
# Mental_Health_Score                 0
# Depression_Score                    0
# Anxiety_Score                       0
# Stress_Level                        0
# Relationship_Status                 0
# Has_Children                        0
# Urban_or_Rural                      0
# Time_Spent_With_Family_Hours        0
# Online_Shopping_Hours               0
# Internet_Connection_Type            0
# Primary_Device_Brand                0
# Has_Screen_Time_Management_App      0
# Self_Reported_Addiction_Level       0
# Monthly_Data_Usage_GB               0
# Has_Night_Mode_On                   0
# Age_First_Phone                     0
# Push_Notifications_Per_Day          0
# Tech_Savviness_Score                0
# dtype: int64

# %%
# To view descriptive statistics
df.describe()
# Out:
#            User_ID          Age    Income_USD  Daily_Screen_Time_Hours  \
# count  3000.000000  3000.000000   3000.000000              3000.000000
# mean   1500.500000    41.307333  29779.511047                 5.984397
# std     866.169729    17.052345  15377.473743                 2.018142
# min       1.000000    12.000000 -25622.660000                -0.500000
# 25%     750.750000    27.000000  19482.705000                 4.597500
# 50%    1500.500000    42.000000  30002.710000                 5.980000
# 75%    2250.250000    56.000000  40352.017500                 7.302500
# max    3000.000000    70.000000  79829.550000                12.870000
#
#        Phone_Unlocks_Per_Day  Social_Media_Usage_Hours  Gaming_Usage_Hours  \
# count            3000.000000               3000.000000         3000.000000
# mean               79.699667                  1.988487            1.486617
# std                25.155683                  0.983224            0.997255
# min                -7.000000                 -1.810000           -1.930000
# 25%                63.000000                  1.340000            0.810000
# 50%                80.000000                  2.010000            1.510000
# 75%                96.000000                  2.640000            2.180000
# max               182.000000                  5.050000            4.860000
#
#        Streaming_Usage_Hours  Messaging_Usage_Hours  Work_Related_Usage_Hours  \
# count            3000.000000             3000.00000               3000.000000
# mean                1.981433                1.48917                  1.995423
# std                 1.004578                0.50883                  0.972245
# min                -1.910000               -0.18000                 -1.160000
# 25%                 1.290000                1.14000                  1.340000
# 50%                 2.010000                1.50000                  1.980000
# 75%                 2.650000                1.84000                  2.670000
# max                 5.180000                3.07000                  5.260000
#
#        Sleep_Hours  Physical_Activity_Hours  Mental_Health_Score  \
# count  3000.000000              3000.000000          3000.000000
# mean      6.492713                 0.996127            50.045053
# std       0.993489                 0.499560            28.738761
# min       2.810000                -0.840000             0.000000
# 25%       5.840000                 0.650000            25.317500
# 50%       6.480000                 1.010000            50.630000
# 75%       7.160000                 1.330000            75.120000
# max      10.320000                 2.800000            99.970000
#
#        Depression_Score  Anxiety_Score  Stress_Level  \
# count       3000.000000    3000.000000   3000.000000
# mean          50.343517      49.918940     49.383413
# std           29.003991      29.041927     28.588983
# min            0.040000       0.010000      0.040000
# 25%           25.665000      24.670000     24.260000
# 50%           50.155000      50.125000     48.800000
# 75%           75.420000      75.400000     74.422500
# max           99.830000     100.000000     99.880000
#
#        Time_Spent_With_Family_Hours  Online_Shopping_Hours  \
# count                   3000.000000            3000.000000
# mean                       1.451450               0.789503
# std                        0.803806               0.505463
# min                       -1.610000              -0.880000
# 25%                        0.920000               0.460000
# 50%                        1.450000               0.780000
# 75%                        1.990000               1.130000
# max                        4.520000               2.600000
#
#        Monthly_Data_Usage_GB  Age_First_Phone  Push_Notifications_Per_Day  \
# count            3000.000000      3000.000000                 3000.000000
# mean               24.871843        13.954000                   99.053667
# std                 9.791275         3.736202                   30.330163
# min               -10.960000         8.000000                  -21.000000
# 25%                18.302500        11.000000                   79.000000
# 50%                25.045000        14.000000                   99.000000
# 75%                31.462500        17.000000                  119.000000
# max                54.850000        20.000000                  204.000000
#
#        Tech_Savviness_Score
# count           3000.000000
# mean              49.457427
# std               28.842681
# min                0.010000
# 25%               23.665000
# 50%               49.150000
# 75%               74.137500
# max               99.940000

# %%
# Categorical Breakdown - By Gender
df['Gender'].value_counts()
# Out:
# Gender
# Male      1047
# Other      990
# Female     963
# Name: count, dtype: int64

# %%
# Categorical Breakdown - By Gender
df['Age'].value_counts().sort_index()
# Out:
# Age
# 12    43
# 13    59
# 14    61
# 15    37
# 16    53
# 17    50
# 18    49
# 19    51
# 20    43
# 21    51
# 22    42
# 23    50
# 24    36
# 25    48
# 26    53
# 27    48
# 28    67
# 29    59
# 30    47
# 31    39
# 32    60
# 33    63
# 34    41
# 35    57
# 36    58
# 37    58
# 38    41
# 39    45
# 40    47
# 41    39
# 42    57
# 43    55
# 44    54
# 45    49
# 46    50
# 47    62
# 48    49
# 49    56
# 50    58
# 51    43
# 52    39
# 53    47
# 54    41
# 55    55
# 56    48
# 57    45
# 58    50
# 59    55
# 60    59
# 61    54
# 62    61
# 63    51
# 64    47
# 65    56
# 66    51
# 67    57
# 68    57
# 69    49
# 70    50
# Name: count, dtype: int64

# %% [markdown]
# **Note**<br>
# ***This dataset was fairly clean to begin with. Gender and age distributions appear balanced — this leads to believe the dataset may be synthetic, since real-world data is rarely this evenly distributed.***

# %%
# filter with .loc function
df.loc[df["Daily_Screen_Time_Hours"] > 5].sort_values("Age", ascending=True)
# Out:
#       User_ID  Country  Age  Gender   Occupation Education_Level  Income_USD  \
# 1932     1933    Japan   12    Male      Student     High School    53068.74
# 2012     2013   Brazil   12  Female   Unemployed             NaN    43883.36
# 1958     1959      USA   12  Female      Student             NaN    17566.36
# 2731     2732    Japan   12    Male      Teacher      Bachelor's    15327.88
# 84         85   Mexico   12  Female      Teacher             NaN    23264.34
# ...       ...      ...  ...     ...          ...             ...         ...
# 1846     1847    China   70    Male      Manager     High School    38826.22
# 2002     2003      USA   70  Female   Unemployed             NaN    27844.91
# 2974     2975   Brazil   70    Male  Salesperson      Bachelor's    36069.44
# 2           3  Germany   70   Other       Doctor     High School    59636.51
# 2989     2990   Russia   70  Female   Unemployed      Bachelor's    36481.02
#
#       Daily_Screen_Time_Hours  Phone_Unlocks_Per_Day  \
# 1932                     7.90                    106
# 2012                     7.52                     30
# 1958                     7.91                     81
# 2731                     5.95                     74
# 84                       9.80                     88
# ...                       ...                    ...
# 1846                     7.99                     70
# 2002                     6.65                     67
# 2974                     7.75                    104
# 2                        5.76                     58
# 2989                     7.07                     59
#
#       Social_Media_Usage_Hours  Gaming_Usage_Hours  Streaming_Usage_Hours  \
# 1932                      0.71                0.78                   3.43
# 2012                      2.37                2.12                   2.79
# 1958                     -0.26                1.61                   2.57
# 2731                      2.86                1.20                   1.47
# 84                        2.53                1.30                   3.14
# ...                        ...                 ...                    ...
# 1846                      2.64                0.63                   3.95
# 2002                      1.92                0.91                  -0.23
# 2974                      1.89                1.47                   3.59
# 2                         2.12                1.96                   1.84
# 2989                      1.11                1.69                   1.81
#
#       Messaging_Usage_Hours  Work_Related_Usage_Hours  Sleep_Hours  \
# 1932                   1.21                      4.12         6.39
# 2012                   1.26                      2.98         5.60
# 1958                   1.63                      1.83         9.13
# 2731                   0.27                      2.73         6.32
# 84                     1.82                      2.49         6.05
# ...                     ...                       ...          ...
# 1846                   2.03                      1.89         6.07
# 2002                   1.92                      1.78         5.72
# 2974                   1.63                      2.03         5.05
# 2                      1.98                      1.92         6.57
# 2989                   1.38                      3.11         6.04
#
#       Physical_Activity_Hours  Mental_Health_Score  Depression_Score  \
# 1932                     0.42                23.51             83.46
# 2012                     1.42                82.96             35.51
# 1958                     0.79                72.69             38.23
# 2731                     1.95                 6.25             57.13
# 84                       0.39                 0.28             58.83
# ...                       ...                  ...               ...
# 1846                     1.41                79.15             94.19
# 2002                    -0.18                82.27             86.65
# 2974                     0.27                32.44             28.11
# 2                        1.93                73.68             44.64
# 2989                     0.97                 2.04              7.89
#
#       Anxiety_Score  Stress_Level Relationship_Status Has_Children  \
# 1932          52.86          4.49     In Relationship           No
# 2012          51.32         33.36     In Relationship          Yes
# 1958          21.40         93.39            Divorced          Yes
# 2731          58.86         39.62            Divorced           No
# 84            12.46         94.93            Divorced          Yes
# ...             ...           ...                 ...          ...
# 1846          79.41         81.79            Divorced          Yes
# 2002          65.31          6.97            Divorced           No
# 2974          89.32         66.18             Married          Yes
# 2             94.47         99.54              Single          Yes
# 2989          81.52         40.70              Single           No
#
#      Urban_or_Rural  Time_Spent_With_Family_Hours  Online_Shopping_Hours  \
# 1932          Urban                          2.73                   0.67
# 2012          Rural                          0.48                   0.79
# 1958          Urban                          2.65                   1.25
# 2731          Rural                          2.61                   0.31
# 84            Urban                          1.68                   0.22
# ...             ...                           ...                    ...
# 1846          Rural                          0.63                   1.03
# 2002          Urban                          1.88                   0.47
# 2974          Rural                         -0.23                   0.77
# 2             Urban                          1.69                  -0.14
# 2989          Urban                          0.70                   1.36
#
#      Internet_Connection_Type Primary_Device_Brand  \
# 1932                       3G              OnePlus
# 2012                     WiFi              OnePlus
# 1958                     WiFi               Xiaomi
# 2731                       5G               Huawei
# 84                         5G              Samsung
# ...                       ...                  ...
# 1846                       3G              OnePlus
# 2002                       5G              OnePlus
# 2974                       4G                Other
# 2                        WiFi              Samsung
# 2989                       4G                Other
#
#      Has_Screen_Time_Management_App Self_Reported_Addiction_Level  \
# 1932                            Yes                           Low
# 2012                            Yes                          High
# 1958                            Yes                           Low
# 2731                            Yes                      Moderate
# 84                               No                      Moderate
# ...                             ...                           ...
# 1846                            Yes                        Severe
# 2002                             No                        Severe
# 2974                             No                      Moderate
# 2                               Yes                        Severe
# 2989                            Yes                      Moderate
#
#       Monthly_Data_Usage_GB Has_Night_Mode_On  Age_First_Phone  \
# 1932                  14.59               Yes               13
# 2012                  20.14               Yes               14
# 1958                  25.81                No               11
# 2731                  22.96                No               16
# 84                    23.17                No               19
# ...                     ...               ...              ...
# 1846                  30.05                No               10
# 2002                  24.07                No               20
# 2974                  21.84                No               13
# 2                     27.45                No               18
# 2989                  22.94               Yes                8
#
#       Push_Notifications_Per_Day  Tech_Savviness_Score
# 1932                         154                  7.29
# 2012                         108                 46.14
# 1958                         153                 27.12
# 2731                          74                 62.26
# 84                           121                 77.98
# ...                          ...                   ...
# 1846                          90                 67.20
# 2002                          61                 81.06
# 2974                         116                 55.65
# 2                             90                 50.27
# 2989                          68                 87.30
#
# [2062 rows x 34 columns]

# %% [markdown]
# #### Step 2: Data Preparation
#
# 1. Checking and removing duplicate rows (By calling the function)
# 2. Renaming column names to match teen_screentime_addiction
# 3. Checking and removing the negative values
# 4. Changing values of User_ID

# %%
# checking for duplicates using functions.py

sys.path.append("..")
from functions import check_duplicates

df = check_duplicates(df, name="global_smartphone_addiction.csv")
# Out:
# global_smartphone_addiction.csv has duplicate rows: 0

# %%
# To view column names
df.columns
# Out:
# Index(['User_ID', 'Country', 'Age', 'Gender', 'Occupation', 'Education_Level',
#        'Income_USD', 'Daily_Screen_Time_Hours', 'Phone_Unlocks_Per_Day',
#        'Social_Media_Usage_Hours', 'Gaming_Usage_Hours',
#        'Streaming_Usage_Hours', 'Messaging_Usage_Hours',
#        'Work_Related_Usage_Hours', 'Sleep_Hours', 'Physical_Activity_Hours',
#        'Mental_Health_Score', 'Depression_Score', 'Anxiety_Score',
#        'Stress_Level', 'Relationship_Status', 'Has_Children', 'Urban_or_Rural',
#        'Time_Spent_With_Family_Hours', 'Online_Shopping_Hours',
#        'Internet_Connection_Type', 'Primary_Device_Brand',
#        'Has_Screen_Time_Management_App', 'Self_Reported_Addiction_Level',
#        'Monthly_Data_Usage_GB', 'Has_Night_Mode_On', 'Age_First_Phone',
#        'Push_Notifications_Per_Day', 'Tech_Savviness_Score'],
#       dtype='str')

# %%
# Rename the columns to match with teen_screentime_addiction.ipynb

df = df.rename(columns={ 'Daily_Screen_Time_Hours': 'Daily_Usage_Hours',
                   'Social_Media_Usage_Hours': 'Time_on_Social_Media',
                   'Gaming_Usage_Hours': 'Time_on_Gaming',
                   'Physical_Activity_Hours': 'Exercise_Hours',
                   'Depression_Score': 'Depression_Level',
                   'Anxiety_Score': 'Anxiety_Level',
                   'Self_Reported_Addiction_Level': 'Addiction_Level'})

# %%
df.head()
# Out:
#    User_ID  Country  Age  Gender   Occupation Education_Level  Income_USD  \
# 0        1    India   32    Male  Salesperson     High School    43865.49
# 1        2       UK   26    Male       Artist        Master's    41868.19
# 2        3  Germany   70   Other       Doctor     High School    59636.51
# 3        4       UK   44  Female     Engineer             NaN    39022.07
# 4        5   Brazil   46   Other      Student             NaN     -783.98
#
#    Daily_Usage_Hours  Phone_Unlocks_Per_Day  Time_on_Social_Media  \
# 0               5.81                     75                  0.84
# 1               9.05                     61                  3.13
# 2               5.76                     58                  2.12
# 3               6.71                     80                  1.60
# 4               6.31                    136                  1.51
#
#    Time_on_Gaming  Streaming_Usage_Hours  Messaging_Usage_Hours  \
# 0           -1.55                   3.36                   1.44
# 1            2.50                   0.80                   2.42
# 2            1.96                   1.84                   1.98
# 3            2.70                   1.90                   2.43
# 4            1.73                   1.48                   1.30
#
#    Work_Related_Usage_Hours  Sleep_Hours  Exercise_Hours  Mental_Health_Score  \
# 0                      2.14         5.22            1.32                61.47
# 1                      1.44         6.23            0.66                96.11
# 2                      1.92         6.57            1.93                73.68
# 3                      1.82         7.27            0.94                53.42
# 4                      1.76         5.43            1.04                67.01
#
#    Depression_Level  Anxiety_Level  Stress_Level Relationship_Status  \
# 0             80.80          23.72         95.80              Single
# 1             98.99          39.72         25.03     In Relationship
# 2             44.64          94.47         99.54              Single
# 3             10.89           5.03         66.49     In Relationship
# 4             37.54          17.29         14.72            Divorced
#
#   Has_Children Urban_or_Rural  Time_Spent_With_Family_Hours  \
# 0           No          Rural                          1.70
# 1           No          Rural                          0.90
# 2          Yes          Urban                          1.69
# 3           No          Urban                          1.11
# 4           No          Urban                          1.06
#
#    Online_Shopping_Hours Internet_Connection_Type Primary_Device_Brand  \
# 0                   1.85                       5G                Other
# 1                   0.66                       4G              Samsung
# 2                  -0.14                     WiFi              Samsung
# 3                   0.17                       3G                Apple
# 4                   0.58                       3G               Xiaomi
#
#   Has_Screen_Time_Management_App Addiction_Level  Monthly_Data_Usage_GB  \
# 0                             No             Low                  16.43
# 1                            Yes          Severe                  32.87
# 2                            Yes          Severe                  27.45
# 3                            Yes        Moderate                  30.85
# 4                             No            High                  10.38
#
#   Has_Night_Mode_On  Age_First_Phone  Push_Notifications_Per_Day  \
# 0               Yes               16                         106
# 1                No               12                         111
# 2                No               18                          90
# 3                No               17                          60
# 4               Yes               18                         127
#
#    Tech_Savviness_Score
# 0                 39.36
# 1                  9.45
# 2                 50.27
# 3                 30.82
# 4                 21.70

# %%
# View columns with negative values

numeric_columns = df.select_dtypes(include='number').columns
negative_counts = (df[numeric_columns] < 0).sum()
negative_counts = negative_counts[negative_counts > 0]
print(negative_counts)
# Out:
# Income_USD                       81
# Daily_Usage_Hours                 9
# Phone_Unlocks_Per_Day             1
# Time_on_Social_Media             70
# Time_on_Gaming                  213
# Streaming_Usage_Hours            67
# Messaging_Usage_Hours             2
# Work_Related_Usage_Hours         53
# Exercise_Hours                   80
# Time_Spent_With_Family_Hours     96
# Online_Shopping_Hours           181
# Monthly_Data_Usage_GB            16
# Push_Notifications_Per_Day        3
# dtype: int64

# %% [markdown]
# ##### Handling negative values in usage/activity columns
#
# Several columns that measure hours or counts contained negative values, which isn't logically possible.
#
# Two possible causes were considered:
# - **Accidental entry error** (e.g. a typo where `1.55` was entered as `-1.55`) — if this were the case, the correct fix would be to take the absolute value, restoring the original intended number.
# - **Synthetic data generation noise** — since both datasets are synthetic (not collected from real people), values were likely generated from a statistical distribution with no built-in floor at 0, allowing some values to fall slightly below zero at random.
#
# Given the fact that the negative values also appear in unrelated columns (e.g. `Income_USD` as low as -25,622, `Push_Notifications_Per_Day` as low as -21), this pattern is more consistent with generator noise than data-entry error. A typo explanation is unlikely to produce negative values that large or that widespread.
#
# Based on this reasoning, negative values in usage/activity columns were treated as invalid and clipped to a minimum of 0 using `.clip(lower=0)`, rather than corrected.

# %%
# Clipping the negative values to zero

columns_to_clip = ['Income_USD','Daily_Usage_Hours','Phone_Unlocks_Per_Day',
                    'Time_on_Social_Media', 'Time_on_Gaming', 'Streaming_Usage_Hours', 
                    'Messaging_Usage_Hours','Work_Related_Usage_Hours','Exercise_Hours',
                    'Time_Spent_With_Family_Hours','Online_Shopping_Hours','Monthly_Data_Usage_GB',
                    'Push_Notifications_Per_Day'
                    ]
df[columns_to_clip] = df[columns_to_clip].clip(lower=0)

# %% [markdown]
# ##### Changing the values of Addiction_level to Numeric to match with Dataset 1
#
# - Dataset 1 - (teen_screentime_addiction) :  Addiction_Level is numeric values from 1-10 <br>
# - Dataset 2 - (global_smartphone_addiction) : Addiction_Level is categorical - Low/Medium/high/Severe
#
# Mapping - Addiction_Level
#
#     Low         -       2.5 (mid range 1-4)
#     Moderate    -       5.5 (mid range 5-6)
#     High        -       7.5 (mid range 7-8)
#     Severe      -       9.5 (mid range 9-10)

# %%
addiction_map = {
    'Low': 2.5,    
    'Moderate': 5.5,
    'High': 7.5,
    'Severe': 9.5  
}

df['Addiction_Level'] = df['Addiction_Level'].map(addiction_map)
df['Addiction_Level'].head()
# Out:
# 0    2.5
# 1    9.5
# 2    9.5
# 3    5.5
# 4    7.5
# Name: Addiction_Level, dtype: float64

# %% [markdown]
# ##### Changing the values of the columns (Anxiety_Level and Depression_Level) to match Dataset 1
#
# - Dataset 1 - (teen_screentime_addiction) :  Anxiety_Level and Depression_Level numeric values from 1-10 <br>
# - Dataset 2 - (global_smartphone_addiction) : Anxiety_Level and Depression_Level numeric values from 1-100
#
# Initial approach :
#
# """
#
# df['Anxiety_Level'] = (df['Anxiety_Level']/10).round(1)
#
# df['Depression_Level'] = (df['Depression_Level']/10).round(1)
#
# df[['Anxiety_Level', 'Depression_Level']].head()
#
# """
#
# This worked the first time, but re-running the cell (e.g. via "Run All") divided the values again each time, causing them to shrink below the intended 1–10 range.
#
# To fix this, `scale_to_ten()` function was created that checks the column's maximum value before dividing. If the max is already within the expected range, the function skips the division — making it safe to re-run without corrupting the data.

# %%
sys.path.append("..")
from functions import scale_to_ten


df = scale_to_ten(df, 'Anxiety_Level')
df = scale_to_ten(df, 'Depression_Level')

df[['Anxiety_Level', 'Depression_Level']].head()
# Out:
#    Anxiety_Level  Depression_Level
# 0            2.4               8.1
# 1            4.0               9.9
# 2            9.4               4.5
# 3            0.5               1.1
# 4            1.7               3.8

# %% [markdown]
# ##### Changing Values of the column named User_ID
#
# **Both Datasets use their own User_ID columns, numbered from 1 to 3000**
#
#  This is will create duplicates during the merging process. To fix this issue, global_smartphone_addiction dataset's User_IDs will offset by adding 10,000 to the current values - shifting its range to 10001–13000

# %%
# Using an if statement to check whether User_ID values don't keep increasing every time "Run All" is used.
# Offset Dataset 2's User_IDs to avoid duplicates with Dataset 1 during the merge

if df['User_ID'].max() < 10000:
    df['User_ID'] = df['User_ID'] + 10000

df['User_ID'].head()
# Out:
# 0    10001
# 1    10002
# 2    10003
# 3    10004
# 4    10005
# Name: User_ID, dtype: int64

# %%
# Average Anxiety level by Sleep Hours and Addiction level

avg_anxiety = df.groupby(['Sleep_Hours','Addiction_Level'])['Anxiety_Level'].mean().reset_index().sort_index().round(2)
avg_anxiety
# Out:
#       Sleep_Hours  Addiction_Level  Anxiety_Level
# 0            2.81              2.5            7.5
# 1            3.51              2.5            5.4
# 2            3.52              2.5            1.6
# 3            3.58              7.5           10.0
# 4            3.60              9.5            2.2
# ...           ...              ...            ...
# 1336         9.58              9.5           10.0
# 1337         9.62              5.5            6.4
# 1338         9.75              9.5            5.2
# 1339         9.84              2.5            5.0
# 1340        10.32              2.5            5.2
#
# [1341 rows x 3 columns]

# %% [markdown]
# ### Step 3 - Data Visualization
#
# **Scatter plot to view the relationship of Sleep_Hours, Addiction_Level and Anxiety_Level**
#
# The scatter plot shows no visible relationship between `Sleep_Hours` and `Anxiety_Level`. Points are spread evenly across the full range of both axes, with no upward or downward trend, and all four addiction levels (2.5, 5.5, 7.5, 9.5) appear mixed throughout the chart rather than occupying distinct regions. People sleeping as little as 3 hours and as much as 9+ hours both show anxiety levels spanning the entire 0–10 range.
#
# This is consistent with the weak correlation (-0.22) observed between `Sleep_Hours` and `Addiction_Level` in Dataset 1 (teen_screentime_addiction), suggesting the lack of a strong relationship may hold across the broader population as well.

# %%
# Scatter plot 

fig, ax = plt.subplots(figsize=(10, 8))

sns.scatterplot(data=df, x='Sleep_Hours', y='Anxiety_Level', hue='Addiction_Level', 
                 palette='coolwarm', alpha=0.8, ax=ax)

fig.suptitle('Sleep Hours vs Anxiety Level', fontweight='bold', color="#772222", fontsize=16)
plt.title('(Survey based on 3000 participants)', fontsize=11, color='black', pad=7)
ax.set_xlabel('Sleep Hours', fontsize=13, color="#772222")
ax.set_ylabel('Anxiety Level (1-10)', fontsize=13, color="#772222")

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['User_ID', 'Country', 'Age', 'Gender', 'Occupation', 'Education_Level',
#        'Income_USD', 'Daily_Usage_Hours', 'Phone_Unlocks_Per_Day',
#        'Time_on_Social_Media', 'Time_on_Gaming', 'Streaming_Usage_Hours',
#        'Messaging_Usage_Hours', 'Work_Related_Usage_Hours', 'Sleep_Hours',
#        'Exercise_Hours', 'Mental_Health_Score', 'Depression_Level',
#        'Anxiety_Level', 'Stress_Level', 'Relationship_Status', 'Has_Children',
#        'Urban_or_Rural', 'Time_Spent_With_Family_Hours',
#        'Online_Shopping_Hours', 'Internet_Connection_Type',
#        'Primary_Device_Brand', 'Has_Screen_Time_Management_App',
#        'Addiction_Level', 'Monthly_Data_Usage_GB', 'Has_Night_Mode_On',
#        'Age_First_Phone', 'Push_Notifications_Per_Day',
#        'Tech_Savviness_Score'],
#       dtype='str')

# %%
df_correlation = df[['Daily_Usage_Hours', 'Time_on_Social_Media', 'Time_on_Gaming', 
                     'Streaming_Usage_Hours', 'Messaging_Usage_Hours', 'Sleep_Hours',
                      'Exercise_Hours', 'Mental_Health_Score', 'Depression_Level',
                       'Anxiety_Level', 'Stress_Level', 'Addiction_Level']].corr()

df_correlation
# Out:
#                        Daily_Usage_Hours  Time_on_Social_Media  \
# Daily_Usage_Hours               1.000000             -0.003551
# Time_on_Social_Media           -0.003551              1.000000
# Time_on_Gaming                  0.016244              0.016785
# Streaming_Usage_Hours           0.005093             -0.000290
# Messaging_Usage_Hours           0.009753             -0.023032
# Sleep_Hours                     0.007133              0.009406
# Exercise_Hours                 -0.005319             -0.010955
# Mental_Health_Score            -0.029462             -0.029115
# Depression_Level               -0.033752              0.018089
# Anxiety_Level                  -0.008279             -0.007749
# Stress_Level                    0.015060             -0.019875
# Addiction_Level                -0.021981             -0.019304
#
#                        Time_on_Gaming  Streaming_Usage_Hours  \
# Daily_Usage_Hours            0.016244               0.005093
# Time_on_Social_Media         0.016785              -0.000290
# Time_on_Gaming               1.000000               0.032914
# Streaming_Usage_Hours        0.032914               1.000000
# Messaging_Usage_Hours        0.030520               0.031375
# Sleep_Hours                 -0.011347               0.003167
# Exercise_Hours              -0.031629              -0.009085
# Mental_Health_Score         -0.018748               0.015506
# Depression_Level             0.015439               0.003098
# Anxiety_Level                0.017357              -0.033684
# Stress_Level                 0.025200              -0.007373
# Addiction_Level              0.000264              -0.015708
#
#                        Messaging_Usage_Hours  Sleep_Hours  Exercise_Hours  \
# Daily_Usage_Hours                   0.009753     0.007133       -0.005319
# Time_on_Social_Media               -0.023032     0.009406       -0.010955
# Time_on_Gaming                      0.030520    -0.011347       -0.031629
# Streaming_Usage_Hours               0.031375     0.003167       -0.009085
# Messaging_Usage_Hours               1.000000    -0.017997        0.024152
# Sleep_Hours                        -0.017997     1.000000        0.001826
# Exercise_Hours                      0.024152     0.001826        1.000000
# Mental_Health_Score                -0.025258     0.011360        0.024285
# Depression_Level                   -0.004746     0.051400        0.012908
# Anxiety_Level                      -0.022665    -0.009080        0.011750
# Stress_Level                        0.027252     0.002822       -0.008741
# Addiction_Level                    -0.002289     0.005289        0.031981
#
#                        Mental_Health_Score  Depression_Level  Anxiety_Level  \
# Daily_Usage_Hours                -0.029462         -0.033752      -0.008279
# Time_on_Social_Media             -0.029115          0.018089      -0.007749
# Time_on_Gaming                   -0.018748          0.015439       0.017357
# Streaming_Usage_Hours             0.015506          0.003098      -0.033684
# Messaging_Usage_Hours            -0.025258         -0.004746      -0.022665
# Sleep_Hours                       0.011360          0.051400      -0.009080
# Exercise_Hours                    0.024285          0.012908       0.011750
# Mental_Health_Score               1.000000          0.018483      -0.013136
# Depression_Level                  0.018483          1.000000      -0.008511
# Anxiety_Level                    -0.013136         -0.008511       1.000000
# Stress_Level                      0.007978         -0.004096       0.043371
# Addiction_Level                  -0.009545          0.002449       0.023034
#
#                        Stress_Level  Addiction_Level
# Daily_Usage_Hours          0.015060        -0.021981
# Time_on_Social_Media      -0.019875        -0.019304
# Time_on_Gaming             0.025200         0.000264
# Streaming_Usage_Hours     -0.007373        -0.015708
# Messaging_Usage_Hours      0.027252        -0.002289
# Sleep_Hours                0.002822         0.005289
# Exercise_Hours            -0.008741         0.031981
# Mental_Health_Score        0.007978        -0.009545
# Depression_Level          -0.004096         0.002449
# Anxiety_Level              0.043371         0.023034
# Stress_Level               1.000000         0.018636
# Addiction_Level            0.018636         1.000000

# %% [markdown]
# #### Heat Map to view the correlation of the variable
#
# Nearly every correlation in this heatmap falls between -0.03 and 0.05, with the only exception being each variable's perfect self-correlation (1.00) on the diagonal. None of the variables show any meaningful linear relationship with one another. This is an unusual result.
#
# In real-world survey data, it's rare for every single variable pair to be this close to zero — even weak but genuine relationships (like the ones commonly seen between sleep and mental health, or screen time and mood) typically produce correlations in the 0.1–0.3 range at minimum. Therefore, the heatmap does not provide a meaningful support for or against the research questions being investigated.

# %%
# To see the correlation of numeric values

fig, ax = plt.subplots(figsize=(14, 14))

sns.heatmap(df_correlation.round(2), annot=True, fmt=".2f", cmap='coolwarm', linewidths=0.5, annot_kws={'size': 10})
plt.suptitle('Global Smartphone Addiction Correlation Map', fontsize=20, color= "#772222", fontweight = 'bold')
plt.title('(Survey based on 3000 Participants (Age Range 12-70))', fontsize=11, color='black', pad=8)
plt.xticks(rotation=90, ha='center', fontsize=12)
plt.yticks(rotation=0, fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Daily Usage analysis using histogram

# %%
#To check the daily usage distribution

fig, ax = plt.subplots(figsize=(12, 12))  
ax.hist(df['Daily_Usage_Hours'], bins=20, alpha=0.9, color= 'steelblue', edgecolor = 'white')

fig.suptitle('Daily Usage Distribution', fontweight = 'bold', color= "#772222" , fontsize=20)
plt.title('(Survey based on 3000 participant (Age Range: 12-70 Years))', fontsize=11, color='black', pad=8)
ax.set_xlabel('Daily phone usage (hours)', fontsize=15,fontweight = 'bold', color= "#772222" )  
ax.set_ylabel('Participant count', fontsize=15,fontweight = 'bold', color= "#772222" )         


mean_value = df['Daily_Usage_Hours'].mean()
ax.axvline(mean_value, color='red', linestyle='--', linewidth=1.5, label=f'Mean: {mean_value:.1f} hrs')
ax.legend()

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.tight_layout()
plt.show()
